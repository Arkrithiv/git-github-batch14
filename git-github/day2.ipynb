# %%
##git

# %%
## git

# %%
# echo "# git-github-batch14" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/Arkrithiv/git-github-batch14.git
# git push -u origin main
